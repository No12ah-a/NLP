# %% [markdown]
# # Importing libraries

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer,WordNetLemmatizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\IT\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\IT\AppData\Roaming\nltk_data...
# True

# %% [markdown]
# # Intializing Text

# %%
text = "NLTK is a powerful library for text processing in NLP"

# %% [markdown]
# # Tokenization

# %%
tokens = word_tokenize(text)
print("Tokens : ",tokens)
# Out:
# Tokens :  ['NLTK', 'is', 'a', 'powerful', 'library', 'for', 'text', 'processing', 'in', 'NLP']

# %%
 import nltk
 nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\IT\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %% [markdown]
# # Stopword removal

# %%
filtered = [w for w in tokens if w.lower() not in stopwords.words('english')]
print("after stopword removal", filtered)
# Out:
# after stopword removal ['NLTK', 'powerful', 'library', 'text', 'processing', '.', 'helps', 'many', 'NLP', 'tasks', '.', 'developers', 'always', 'improving', 'functionalities', '.']

# %% [markdown]
# # Stemming

# %%
stemmer = PorterStemmer()
stems = [stemmer.stem(word) for word in filtered]
print("stemmed words : ", stems)
# Out:
# stemmed words :  ['nltk', 'power', 'librari', 'text', 'process', 'nlp']

# %% [markdown]
# # Lemmatization

# %%
lemmatizer = WordNetLemmatizer()
lemmas = [lemmatizer.lemmatize(word) for word in filtered]
print(lemmas)
# Out:
# ['NLTK', 'powerful', 'library', 'text', 'processing', 'NLP']

# %% [markdown]
# # Tokenize the text file

# %%
file_path = r'C:\Users\IT\Desktop\sample.txt'
with open(file_path, 'r') as file:
    text = file.read()

# %%
tokens = word_tokenize(text)
print("Tokens : ",tokens)
# Out:
# Tokens :  ['NLTK', 'is', 'a', 'powerful', 'library', 'for', 'text', 'processing', '.', 'It', 'helps', 'with', 'many', 'NLP', 'tasks', '.', 'The', 'developers', 'are', 'always', 'improving', 'its', 'functionalities', '.']

# %% [markdown]
# # Stopword removal

# %%
filtered = [w for w in tokens if w.lower() not in stopwords.words('english')]
print("after stopword removal", filtered)
# Out:
# after stopword removal ['NLTK', 'powerful', 'library', 'text', 'processing', '.', 'helps', 'many', 'NLP', 'tasks', '.', 'developers', 'always', 'improving', 'functionalities', '.']
